# %% [markdown]
# # Importing libraries

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# ## link to the website

# %% [markdown]
# considering flipkart website of mobiles which are under 50K

# %%
link = 'https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %% [markdown]
# sending & receiving response

# %%
res = requests.get(link)
soup = BeautifulSoup(res.text,'html.parser')

# %% [markdown]
# HTML file of the website

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Scrapping each mobile data from multiple pages

# %%
data = []

for page in tqdm(range(1,413)):
    page_link = 'https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=' + str(page)
    
    res = requests.get(page_link)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    for sp in soup.find_all('div', class_='_75nlfW'):
        try:
            name = sp.find('div', class_='KzDlHZ').text
        except:
            name = np.nan
        try:
            price = sp.find('div', class_='Nx9bqj _4b5DiR').text
        except:
            price = np.nan
        try:
            img_link = sp.find('img', class_='DByuf4').get('src')
        except:
            img_link = np.nan
        try:
            prod_link = 'https://www.flipkart.com' + sp.find('a', class_='CGtC98').get('href')
        except:
            prod_link = np.nan
        try:
            rating = sp.find('span', class_='Wphh3N').text.split('&')[0][:-1]
        except:
            rating = np.nan
        try:
            reviews = sp.find('span', class_='Wphh3N').text.split('&')[1][1:]
        except:
            reviews = np.nan
        data.append([name, img_link, price, rating, reviews, prod_link])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 412/412 [07:07<00:00,  1.04s/it]

# %%
len(data)
# Out:
# 912

# %% [markdown]
# ## converting into DATAFRAME

# %%
df = pd.DataFrame(data,columns=['product_name','prod_img_link','price','rating','reviews','prod_link'])

# %%
df.head()
# Out:
#                               product_name  \
# 0    Nothing Phone (2a) 5G (Black, 128 GB)
# 1     OnePlus 11R 5G (Sonic Black, 256 GB)
# 2          OnePlus 12R (Cool Blue, 256 GB)
# 3          OnePlus 12R (Iron Grey, 256 GB)
# 4  vivo V30 Pro 5G (Classic Black, 512 GB)
#
#                                        prod_img_link    price          rating  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...  ₹23,999  19,732 Ratings
# 1  https://rukminim2.flixcart.com/image/312/312/x...  ₹36,770  10,471 Ratings
# 2  https://rukminim2.flixcart.com/image/312/312/x...  ₹43,793     747 Ratings
# 3  https://rukminim2.flixcart.com/image/312/312/x...  ₹44,813     747 Ratings
# 4  https://rukminim2.flixcart.com/image/312/312/x...  ₹46,999     758 Ratings
#
#          reviews                                          prod_link
# 0  2,894 Reviews  https://www.flipkart.com/nothing-phone-2a-5g-b...
# 1    797 Reviews  https://www.flipkart.com/oneplus-11r-5g-sonic-...
# ...

# %% [markdown]
# ## Saving the Dataframe into external file

# %%
df.to_excel("flipkart mobile scrapping.xlsx",index=False)
